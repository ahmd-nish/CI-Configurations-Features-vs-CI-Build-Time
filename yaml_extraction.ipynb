# %% [markdown]
# # CI Workflow YAML Parsing & Feature Extraction Pipeline

# %%
import yaml
import logging
import pandas as pd
from pathlib import Path

# %%
# ─── Setup ────────────────────────────────────────────────────────────────────
logging.basicConfig(level=logging.INFO, format="%(asctime)s %(levelname)s %(message)s")
logger = logging.getLogger("ci_analysis_sample")

CONFIG_ROOT = Path("ci_configs")
OUT_CSV     = Path("workflow_features.csv")
AGG_OUT_CSV     = Path("aggregatED_workflow_features.csv")

# %% [markdown]
# ### `extract_features(path: Path)`
#
# Parses a single workflow YAML and returns:
#
# - **`runs_on`**: set of runner labels (e.g. `ubuntu-latest`)
# - **`n_jobs`** / **`n_steps`**: count of jobs and total steps
# - **`uses_cache`** / **`has_matrix`**: booleans for cache action and matrix strategy
#
# Skips invalid YAML and infers `owner`/`repo` from the folder name.

# %%
# ─── Extraction function (as before) ──────────────────────────────────────────
def extract_features(path: Path):
    try:
        data = yaml.safe_load(path.read_text())
        if not isinstance(data, dict):
            raise ValueError("Top‐level not a mapping")
    except Exception as e:
        logger.warning(f"Skipping {path.name}: YAML error: {e}")
        return None

    owner, repo = path.parent.name.split("--",1)
    jobs = data.get("jobs",{}) or {}

    # runs_on
    runs_on = set()
    for job in jobs.values():
        r = job.get("runs-on") or job.get("runs_on")
        if isinstance(r, str): runs_on.add(r)
        elif isinstance(r, list): runs_on.update(r)

    # counts
    n_jobs  = len(jobs)
    n_steps = sum(len(job.get("steps",[])) for job in jobs.values() if isinstance(job.get("steps"),list))

    # cache, matrix
    uses_cache = any(
        isinstance(step,dict) and "actions/cache" in step.get("uses","")
        for job in jobs.values() for step in job.get("steps",[])
    )
    has_matrix = any(
        isinstance(job.get("strategy"),dict) and "matrix" in job["strategy"]
        for job in jobs.values()
    )

    return {
        "owner": owner, "repo": repo,
        "workflow_file": path.name,
        "runs_on": list(runs_on),
        "n_jobs": n_jobs, "n_steps": n_steps,
        "uses_cache": uses_cache, "has_matrix": has_matrix
    }

# %%
records = []
folders = sorted(CONFIG_ROOT.iterdir())
logger.info(f"Sampling first {len(folders)} repos in {CONFIG_ROOT}")

for repo_dir in folders:
    for yml in repo_dir.glob("*.yml"):
        rec = extract_features(yml)
        if rec:
            records.append(rec)
# Out:
# 2025-06-27 00:28:01,483 INFO Sampling first 14764 repos in ci_configs
# 2025-06-27 00:28:02,738 WARNING Skipping test.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:02,775 WARNING Skipping daily-update-black-contract.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:03,269 WARNING Skipping auto-comment-on-close.yml: YAML error: expected '<document start>', but found '<block mapping start>'
#   in "<unicode string>", line 3, column 1:
#     on:
#     ^
# 2025-06-27 00:28:04,171 WARNING Skipping my-workflow.yml: YAML error: mapping values are not allowed here
#   in "<unicode string>", line 11, column 8:
#        uses: actions/checkout@v2
#            ^
# 2025-06-27 00:28:04,928 WARNING Skipping deploy.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:05,767 WARNING Skipping nowsecure.yml: YAML error: while constructing a mapping
#   in "<unicode string>", line 47, column 21:
#               group_id: {{ groupId }}                 #  ...
#                         ^
# found unhashable key
#   in "<unicode string>", line 47, column 22:
#               group_id: {{ groupId }}                 # U ...
#                          ^
# 2025-06-27 00:28:05,932 WARNING Skipping nowsecure-mobile-sbom.yml: YAML error: while constructing a mapping
#   in "<unicode string>", line 55, column 21:
#               group_id: {{ groupId }}                 #  ...
#                         ^
# found unhashable key
#   in "<unicode string>", line 55, column 22:
#               group_id: {{ groupId }}                 # U ...
#                          ^
# 2025-06-27 00:28:06,471 WARNING Skipping build.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:06,984 WARNING Skipping auto-comment.yml: YAML error: while parsing a block mapping
#   in "<unicode string>", line 14, column 2:
#      respond-to-events:
#      ^
# expected <block end>, but found '-'
#   in "<unicode string>", line 22, column 2:
#      - name: Respond to new issues
#      ^
# 2025-06-27 00:28:07,391 WARNING Skipping release_workflow.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:07,446 WARNING Skipping auto-comment.yml: YAML error: while parsing a block mapping
#   in "<unicode string>", line 14, column 2:
#      respond-to-events:
#      ^
# expected <block end>, but found '-'
#   in "<unicode string>", line 22, column 2:
#      - name: Respond to new issues
#      ^
# 2025-06-27 00:28:07,747 WARNING Skipping releases.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 28, column 14:
#               tag	: ${{ steps.changelog.outputs.t ...
#                  ^
# 2025-06-27 00:28:07,921 WARNING Skipping node.js.yml: YAML error: expected '<document start>', but found '<block mapping start>'
#   in "<unicode string>", line 4, column 1:
#     name: Node.js CI
#     ^
# 2025-06-27 00:28:09,038 WARNING Skipping node.js.yml: YAML error: mapping values are not allowed here
#   in "<unicode string>", line 35, column 13:
#               if: failure()
#                 ^
# 2025-06-27 00:28:09,277 WARNING Skipping close-old-pr.yml: YAML error: mapping values are not allowed here
#   in "<unicode string>", line 2, column 5:
#     name: Close Stale PRs
#         ^
# 2025-06-27 00:28:09,282 WARNING Skipping autocomment-iss-close.yml: YAML error: mapping values are not allowed here
#   in "<unicode string>", line 2, column 5:
#     name: Comment on Issue Close
#         ^
# 2025-06-27 00:28:09,284 WARNING Skipping close-old-issue.yml: YAML error: mapping values are not allowed here
#   in "<unicode string>", line 2, column 5:
#     name: Close Old Issues
#         ^
# 2025-06-27 00:28:09,338 WARNING Skipping Greetings.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:09,370 WARNING Skipping main.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:10,824 WARNING Skipping deploy_stage.yml: YAML error: mapping values are not allowed here
#   in "<unicode string>", line 46, column 122:
#      ... LS_SERVICES_STAGE }}        uses: adobe/aio-apps-action@2.0.1
#                                          ^
# 2025-06-27 00:28:11,460 WARNING Skipping dev-workflow-p1.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:11,580 WARNING Skipping stage-workflow-p1.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:11,589 WARNING Skipping tests.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:11,804 WARNING Skipping releases.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 28, column 14:
#               tag	: ${{ steps.changelog.outputs.t ...
#                  ^
# 2025-06-27 00:28:12,917 WARNING Skipping closeissues.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:12,997 WARNING Skipping translate.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:16,213 WARNING Skipping label.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:19,013 WARNING Skipping stale.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:20,211 WARNING Skipping githubio.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 19, column 90:
#      ... jun/devtools:${{ github.ref_name	}}
#                                          ^
# 2025-06-27 00:28:21,526 WARNING Skipping upload-release.yml: YAML error: unacceptable character #x0008: special characters are not allowed
#   in "<unicode string>", position 1454
# 2025-06-27 00:28:21,824 WARNING Skipping karma-tests.yml: YAML error: while scanning a simple key
#   in "<unicode string>", line 15, column 5:
#         envp
#         ^
# could not find expected ':'
#   in "<unicode string>", line 16, column 13:
#          DISPLAY: :99.0
#                 ^
# 2025-06-27 00:28:24,304 WARNING Skipping test-functional-local-safari.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 1, column 37:
#     name: Test Functional (Local Safari)
#                                         ^
# 2025-06-27 00:28:25,527 WARNING Skipping auto.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:26,920 WARNING Skipping security.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:28,067 WARNING Skipping deploy-script.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 51, column 33:
#             if: ${{github.event_name	!= 'schedule' }}
#                                     ^
# 2025-06-27 00:28:28,853 WARNING Skipping stale.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:37,239 WARNING Skipping test.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 8, column 42:
#      ... on: blacksmith-8vcpu-ubuntu-2204
#                                          ^
# 2025-06-27 00:28:40,408 WARNING Skipping deploy-website.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 84, column 10:
#         push:
#              ^
# 2025-06-27 00:28:40,504 WARNING Skipping lint.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:40,652 WARNING Skipping FUNDING.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:41,687 WARNING Skipping pr_check.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:42,244 WARNING Skipping test-json-data-extraction.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:42,255 WARNING Skipping check-dist.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:43,158 WARNING Skipping main.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:43,163 WARNING Skipping workflow_ubuntu_docker-ubuntu.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 19, column 57:
#      ... se status' in a Docker Container
#                                          ^
# 2025-06-27 00:28:43,949 WARNING Skipping nodejs.yml: YAML error: mapping values are not allowed here
#   in "<unicode string>", line 25, column 17:
#                 uses: actions/setup-node@v1
#                     ^
# 2025-06-27 00:28:44,900 WARNING Skipping nodejs.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 22, column 14:
#         strategy:
#                  ^
# 2025-06-27 00:28:45,740 WARNING Skipping server.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 4, column 27:
#       AWS_REGION: il-central-1
#                               ^
# 2025-06-27 00:28:45,897 WARNING Skipping level2-smoker.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:46,673 WARNING Skipping cron.yml: YAML error: mapping values are not allowed here
#   in "<unicode string>", line 14, column 57:
#      ... rets.GITHUB_TOKEN }}      - name: Setup Node.js
#                                          ^
# 2025-06-27 00:28:47,929 WARNING Skipping release.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:47,930 WARNING Skipping publish.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:47,978 WARNING Skipping npmpublish.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 43, column 13:
#             env:
#                 ^
# 2025-06-27 00:28:47,987 WARNING Skipping npm-publish.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 40, column 13:
#             env:
#                 ^
# 2025-06-27 00:28:48,915 WARNING Skipping assigner.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:48,920 WARNING Skipping linting.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:56,694 WARNING Skipping dependabot.yml: YAML error: mapping values are not allowed here
#   in "<unicode string>", line 6, column 8:
#     version: 2
#            ^
# 2025-06-27 00:28:57,424 WARNING Skipping codesee-arch-diagram.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:58,660 WARNING Skipping releases.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 28, column 14:
#               tag	: ${{ steps.changelog.outputs.t ...
#                  ^
# 2025-06-27 00:28:58,795 WARNING Skipping php.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:28:59,431 WARNING Skipping validate-pubnub-yml.yml: YAML error: while parsing a block mapping
#   in "<unicode string>", line 8, column 3:
#       build:
#       ^
# expected <block end>, but found '<block mapping start>'
#   in "<unicode string>", line 10, column 5:
#         runs-on:
#         ^
# 2025-06-27 00:28:59,432 WARNING Skipping validate-pubnub-yml.yml: YAML error: while parsing a block mapping
#   in "<unicode string>", line 8, column 3:
#       build:
#       ^
# expected <block end>, but found '<block mapping start>'
#   in "<unicode string>", line 10, column 5:
#         runs-on:
#         ^
# 2025-06-27 00:29:00,339 WARNING Skipping deploy-script.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 51, column 33:
#             if: ${{github.event_name	!= 'schedule' }}
#                                     ^
# 2025-06-27 00:29:00,736 WARNING Skipping playwright-e2e.yml: YAML error: while parsing a block mapping
#   in "<unicode string>", line 35, column 11:
#               GITHUB_TOKEN: ${{secrets.GITHUB_ ...
#               ^
# expected <block end>, but found '-'
#   in "<unicode string>", line 36, column 11:
#               - name: Install dependencies
#               ^
# 2025-06-27 00:29:00,744 WARNING Skipping issue-lock.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:29:01,172 WARNING Skipping lint.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:29:01,173 WARNING Skipping test.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:29:04,165 WARNING Skipping stale.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 20, column 39:
#      ...   exempt-issue-labels: 'feature'
#                                          ^
# 2025-06-27 00:29:04,330 WARNING Skipping Update Yonode Package.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:29:04,622 WARNING Skipping node.js.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 78, column 13:
#         runs-on:	macos-latest
#                 ^
# 2025-06-27 00:29:06,114 WARNING Skipping deploy.yml: YAML error: while scanning for the next token
# found character '\t' that cannot start any token
#   in "<unicode string>", line 51, column 33:
#             if: ${{github.event_name	!= 'schedule' }}
#                                     ^
# 2025-06-27 00:29:08,677 WARNING Skipping windows-node.js.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:29:14,385 WARNING Skipping ci.yml: YAML error: while parsing a block mapping
#   in "<unicode string>", line 31, column 7:
#         - name: Cache Yarn Dependencies
#           ^
# expected <block end>, but found '-'
#   in "<unicode string>", line 42, column 7:
#           - name: Install dependencies
#           ^
# 2025-06-27 00:29:16,820 WARNING Skipping deploy.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:29:17,980 WARNING Skipping deploy-to-pages.yml: YAML error: Top‐level not a mapping
# 2025-06-27 00:29:17,981 WARNING Skipping main.yml: YAML error: Top‐level not a mapping

# %%
df = pd.DataFrame(records)
df.to_csv(OUT_CSV, index=False)
logger.info(f"Wrote {len(df)} feature rows to {OUT_CSV}")
# Out:
# 2025-06-27 00:33:15,545 INFO Wrote 27756 feature rows to workflow_features.csv

# %%
# aggregate to one row per (owner,repo)
repo_df = (
    df
    .groupby(["owner","repo"], as_index=False)
    .agg({
        "runs_on":    lambda lists: sorted({os for lst in lists for os in lst}),
        "n_jobs":     "sum",
        "n_steps":    "sum",
        "uses_cache": "max",   # True if any workflow uses cache
        "has_matrix": "max"    # True if any workflow has matrix
    })
)

# write out the per‐repo features
repo_df.to_csv(AGG_OUT_CSV, index=False)
logger.info(f"Wrote {len(repo_df)} repo‐level feature rows to {OUT_CSV}")
# Out:
# 2025-06-27 00:41:42,115 INFO Wrote 13730 repo‐level feature rows to workflow_features.csv

# %% [markdown]
# ### Integrating CI Runtime Metrics with Workflow Configuration Features
#
# This script loads GitHub Actions run metadata (`build_runs.csv`) and aggregated workflow configuration features (`aggregated_workflow_features.csv`), then performs an inner join on `owner` and `repo` to retain only repositories present in both datasets, producing a unified table (`ci_runs_with_workflow_features.csv`) for further analysis.

# %%
import pandas as pd
import ast

# 1) Load CI run metadata
ci_runs_df = pd.read_csv(
    "build_runs.csv",    # replace with your actual CI runs filename
    parse_dates=["run_started_at", "updated_at"]
)
ci_runs_df["duration_minutes"] = (
    ci_runs_df["updated_at"] - ci_runs_df["run_started_at"]
).dt.total_seconds() / 60

# 2) Load aggregated workflow features
workflow_features_df = pd.read_csv(
    "aggregated_workflow_features.csv",  # replace with your actual features filename
    converters={"runs_on": ast.literal_eval}
)

# 3) Keep only repos present in both datasets
combined_df = pd.merge(
    left=ci_runs_df,
    right=workflow_features_df,
    on=["owner", "repo"],
    how="inner",
    suffixes=("_run", "_workflow")
)

print(f"CI runs records:       {len(ci_runs_df)}")
print(f"Workflow features:     {len(workflow_features_df)}")
print(f"Records in both sets:  {len(combined_df)}")

# 4) Preview the merged table
print(combined_df.head())

# 5) Optionally save for further analysis
combined_df.to_csv("ci_runs_with_workflow_features.csv", index=False)
# Out:
# CI runs records:       12675
# Workflow features:     13730
# Records in both sets:  11800
#            owner              repo       run_id  run_number  workflow_id  \
# 0        dgarijo            widoco  13308358456         395     24445829
# 1   snowballstem  snowball-website  15717069293         155     70994949
# 2         apache   cordova-android  15840192717        1313       457902
# 3  sumeetchhetri              gatf  15052293010           2    155241087
# 4        vert-x3        vertx-unit  15894194436          40    163702269
#
#                                        workflow_name     event head_branch  \
# 0                                                 CI      push      master
# 1                                     Update website      push        main
# 2                                            Node CI      push      master
# 3  maven in /. for io.github.bonigarcia:webdriver...   dynamic      master
# 4                            vertx-unit (5.x-stable)  schedule      master
#
#                                    head_sha     status  ...  \
# 0  5d9b0e77cf4fba6323600a9f36995a2c1a1aab8e  completed  ...
# 1  6b808b1807cfdf5cae4dc89c50ea5dc72a76a3e5  completed  ...
# 2  484c60e48362952d26ce6b0dd90116f5811c27b7  completed  ...
# 3  26cd57b04659729161172721eafd9c5ca28ce35a  completed  ...
# 4  28b8f6c479d6c3a42c608ea236cd56d9c54f3b58  completed  ...
#
#                                             html_url job_count  \
# 0  https://github.com/dgarijo/Widoco/actions/runs...         4
# 1  https://github.com/snowballstem/snowball-websi...         1
# 2  https://github.com/apache/cordova-android/acti...         9
# 3  https://github.com/sumeetchhetri/gatf/actions/...         1
# 4  https://github.com/vert-x3/vertx-unit/actions/...         3
#
#                                         runner_names duration_min  \
# 0  GitHub Actions 12,GitHub Actions 23,GitHub Act...     1.366667
# 1                          GitHub Actions 1000004065     2.050000
# 2  GitHub Actions 1000720800,GitHub Actions 10007...    13.666667
# 3                          GitHub Actions 1000000028     0.600000
# 4  GitHub Actions 1000486520,GitHub Actions 10004...     1.616667
#
#   duration_minutes                            runs_on n_jobs  n_steps  \
# 0         1.366667                    [ubuntu-latest]      2       10
# 1         2.050000                    [ubuntu-latest]      1        7
# 2        13.666667  [${{ matrix.os }}, ubuntu-latest]      2       13
# 3         0.600000                    [ubuntu-latest]      3       22
# 4         1.616667  [${{ inputs.os }}, ubuntu-latest]      8        7
#
#    uses_cache has_matrix
# 0       False       True
# 1       False      False
# 2       False       True
# 3       False       True
# 4       False       True
#
# [5 rows x 24 columns]
